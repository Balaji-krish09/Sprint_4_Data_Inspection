# %%
import json

notebook_content = {
    "cells": [
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": ["# Notebook 1: Dataset Understanding"],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "import pandas as pd\n",
                "\n",
                "# Load the customer dataset\n",
                'df = pd.read_csv("Customer_Data.csv")\n',
                "df.head()",
            ],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "#### Dataset Overview\n",
                "- **Dataset Name:** Customer Retention & Churn Dataset\n",
                "- **Dataset Source:** Sprint 4 Practice Dataset derived from simulated telecom customer metrics.\n",
                "- **File Name:** `Customer_Data.csv`",
            ],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "| Column | Type | Description |\n",
                "| :--- | :--- | :--- |\n",
                "| `CustomerID` | Identifier | Unique identifier assigned to each customer |\n",
                "| `Age` | Numerical / Continuous | Age of the customer in years |\n",
                "| `Gender` | Categorical | Customer gender (Male / Female) |\n",
                "| `TenureYears` | Numerical / Discrete | Total length of time customer has stayed with service |\n",
                "| `MonthlyCharges` | Numerical / Continuous | Current monthly billing amount ($) |\n",
                "| `TotalCharges` | Numerical / Continuous | Cumulative charges accrued ($) |\n",
                "| `ContractType` | Categorical | Subscription structure (Month-to-month, One year, Two year) |\n",
                "| `InternetService` | Categorical | Network connection provision (DSL, Fiber optic, No) |\n",
                "| `PaymentMethod` | Categorical | Selected payment mechanism |\n",
                "| `SeniorCitizen` | Categorical | Senior citizen status classification (Yes / No) |\n",
                "| `SupportCalls` | Numerical / Discrete | Count of customer service interactions |\n",
                "| `StreamingService` | Categorical | Active streaming addon status (Yes / No) |\n",
                "| `PaperlessBilling` | Categorical | Digital billing opt-in preference (Yes / No) |\n",
                "| `Churn` | Categorical / Target | Indicates whether customer left the service (Yes / No) |\n",
            ],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 1. Dataset\n",
                "A **Dataset** is a structured collection of related data points arranged in rows (records/observations) and columns (attributes/features).\n\n",
                "**Real-World Context:**\n",
                "In customer analytics, a dataset aggregates demographic, operational, and financial dimensions to give a holistic view of customer behavior.",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": ["df.head(10)"],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 2. Feature\n",
                "A **Feature** is an individual measurable property or characteristic of an observed entity (a single column in a tabular dataset).\n\n",
                "**Real-World Context:**\n",
                "Attributes like `MonthlyCharges`, `TenureYears`, and `ContractType` serve as descriptive features for analyzing account retention.",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "features = df.columns\n",
                "print('Dataset Features (Columns):')\n",
                "print(list(features))",
            ],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 3. Target\n",
                "The **Target** is the primary variable of interest that a predictive model aims to estimate, forecast, or classify.\n\n",
                "**Real-World Context:**\n",
                "Here, `Churn` is our target outcome: determining if a subscriber remains active (`No`) or terminates service (`Yes`).",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": ["target = 'Churn'\n", "print(df[target].head())"],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 4. Independent Variables\n",
                "**Independent Variables** (also known as predictors or inputs) are the attributes used to model, explain, or forecast changes in the target variable.\n\n",
                "**Real-World Context:**\n",
                "Features such as `SupportCalls` and `MonthlyCharges` are independent inputs used to model whether a customer might churn.",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": ["X = df.drop(columns=['Churn'])\n", "X.head()"],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 5. Dependent Variable\n",
                "The **Dependent Variable** relies directly on the inputs/independent variables. Its value is what the model attempts to predict.\n\n",
                "**Real-World Context:**\n",
                "`Churn` represents our dependent variable in this classification pipeline.",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": ["y = df['Churn']\n", "y.head()"],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 6. Numerical Features\n",
                "**Numerical Features** consist of quantitative measurements (integers or floats) that allow standard mathematical operations like averaging and scaling.\n\n",
                "**Examples in Dataset:**\n",
                "`Age`, `TenureYears`, `MonthlyCharges`, `TotalCharges`, `SupportCalls`.",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "num_cols = df.select_dtypes(include=['number']).columns\n",
                "print('Numerical Columns:', list(num_cols))\n",
                "df[num_cols].describe()",
            ],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 7. Categorical Features\n",
                "**Categorical Features** capture qualitative properties or discrete group labels rather than continuous numeric measurements.\n\n",
                "**Examples in Dataset:**\n",
                "`Gender`, `ContractType`, `InternetService`, `PaymentMethod`, `PaperlessBilling`.",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "cat_cols = df.select_dtypes(include=['object']).columns\n",
                "print('Categorical Columns:', list(cat_cols))",
            ],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 8. Discrete Features\n",
                "**Discrete Features** are numerical variables that take distinct, countable integer values (typically counts or distinct steps).\n\n",
                "**Real-World Context:**\n",
                "`SupportCalls` represents a discrete numerical feature because a customer makes whole-number calls (e.g., 0, 1, 2 calls).",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": ["df['SupportCalls'].head(10)"],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 9. Continuous Features\n",
                "**Continuous Features** can assume an infinite number of real-valued fractional or floating-point quantities within a given interval.\n\n",
                "**Real-World Context:**\n",
                "`MonthlyCharges` and `TotalCharges` represent continuous financial amounts (e.g., $20.41, $131.92).",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": ["df[['MonthlyCharges', 'TotalCharges']].head(10)"],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 10. Identifier Columns\n",
                "An **Identifier Column** contains unique values designed to isolate single records. Primary identifiers carry no predictive pattern for Machine Learning modeling and are typically removed prior to training.\n\n",
                "**Real-World Context:**\n",
                "`CustomerID` uniquely tracks accounts but does not predict retention behaviors.",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": ["df['CustomerID'].head()"],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 11. Target Variable\n",
                "Analyzing the class distribution of our **Target Variable** helps determine baseline balance and task structure (binary classification).\n\n",
                "**Distribution Overview:**",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "print('Class Counts:')\n",
                "print(df['Churn'].value_counts())\n",
                "print('\\nClass Percentages:')\n",
                "print(df['Churn'].value_counts(normalize=True) * 100)",
            ],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 12. Metadata\n",
                "**Metadata** summarizes operational properties about the dataset structure, data types, memory footprints, and non-null counts.",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": ["df.info()"],
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 13. Dataset Dimensions\n",
                "**Dataset Dimensions** express the overall shape of the data matrix in terms of total rows (records) and total columns (attributes).",
            ],
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "rows, cols = df.shape\n",
                "print(f'Total Rows (Observations): {rows}')\n",
                "print(f'Total Columns (Variables): {cols}')",
            ],
        },
    ],
    "metadata": {
        "language_info": {"name": "python"},
        "kernelspec": {
            "display_name": "Python 3",
            "language": "python",
            "name": "python3",
        },
    },
    "nbformat": 4,
    "nbformat_minor": 2,
}

with open("01_Dataset_Understanding.ipynb", "w", encoding="utf-8") as f:
    json.dump(notebook_content, f, indent=2)

print(
    "Successfully created 01_Dataset_Understanding.ipynb in your workspace!"
)
# Out:
# Successfully created 01_Dataset_Understanding.ipynb in your workspace!
